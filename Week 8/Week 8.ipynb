# %%
from urllib.request import urlopen
target_url0 = 'http://www.gutenberg.org/files/135/135-0.txt'
book_raw = urlopen(target_url0).read().decode('utf-8')

# %%
len(book_raw)
# Out:
# 3324222

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/mohdtalibakhtar/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.tokenize import word_tokenize

word_tokens  = word_tokenize(book_raw)
word_tokens
# Out:
# ['\ufeffThe',
#  'Project',
#  'Gutenberg',
#  'eBook',
#  'of',
#  'Les',
#  'Misérables',
#  ',',
#  'by',
#  'Victor',
#  'Hugo',
#  'This',
#  'eBook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'in',
#  'the',
#  'United',
#  'States',
#  'and',
#  'most',
#  'other',
#  'parts',
#  'of',
#  'the',
#  'world',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restrictions',
#  'whatsoever',
#  '.',
#  'You',
#  'may',
#  'copy',
#  'it',
#  ',',
#  'give',
#  'it',
#  'away',
#  'or',
#  're-use',
#  'it',
#  'under',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'Project',
#  'Gutenberg',
#  'License',
#  'included',
#  'with',
#  'this',
#  'eBook',
#  'or',
#  'online',
#  'at',
#  'www.gutenberg.org',
#  '.',
#  'If',
#  'you',
#  'are',
#  'not',
#  'located',
#  'in',
#  'the',
#  'United',
#  'States',
#  ',',
#  'you',
#  'will',
#  'have',
#  'to',
#  'check',
#  'the',
#  'laws',
#  'of',
#  'the',
# ...

# %%
from nltk.tokenize import sent_tokenize
Miserables_sentences = sent_tokenize(book_raw)
Miserables_sentences
# Out:
# ['\ufeffThe Project Gutenberg eBook of Les Misérables, by Victor Hugo\r\n\r\nThis eBook is for the use of anyone anywhere in the United States and\r\nmost other parts of the world at no cost and with almost no restrictions\r\nwhatsoever.',
#  'You may copy it, give it away or re-use it under the terms\r\nof the Project Gutenberg License included with this eBook or online at\r\nwww.gutenberg.org.',
#  'If you are not located in the United States, you\r\nwill have to check the laws of the country where you are located before\r\nusing this eBook.',
# ...

# %% [markdown]
# ## Exercises 1: Lengthy Books

# %%
target_url = 'https://www.gutenberg.org/files/1184/1184-0.txt'
book1 = urlopen(target_url).read().decode('utf-8')
len(book1)
# Out:
# 2708279

# %%
target_url2 = 'https://www.gutenberg.org/files/2600/2600-0.txt'
book2 = urlopen(target_url2).read().decode('utf-8')
len(book2)
# Out:
# 3293552

# %%
target_url3 = 'http://www.gutenberg.org/cache/epub/2000/pg2000.txt'
book3 = urlopen(target_url3).read().decode('utf-8')
len(book3)
# Out:
# 2168028

# %%
target_url4 = 'https://www.gutenberg.org/cache/epub/996/pg996.txt'
book4 = urlopen(target_url4).read().decode('utf-8')
len(book4)
# Out:
# 2361840

# %%
from nltk.tokenize import sent_tokenize
Miserables_sentences = sent_tokenize(book_raw)
Miserables_sentences
# Out:
# ['\ufeffThe Project Gutenberg eBook of Les Misérables, by Victor Hugo\r\n\r\nThis eBook is for the use of anyone anywhere in the United States and\r\nmost other parts of the world at no cost and with almost no restrictions\r\nwhatsoever.',
#  'You may copy it, give it away or re-use it under the terms\r\nof the Project Gutenberg License included with this eBook or online at\r\nwww.gutenberg.org.',
#  'If you are not located in the United States, you\r\nwill have to check the laws of the country where you are located before\r\nusing this eBook.',
# ...

# %%
len(Miserables_sentences)
# Out:
# 30079

# %%
from nltk import FreqDist 
fdist_example = FreqDist(book4)
fdist_example
# Out:
# FreqDist({' ': 395404, 'e': 216337, 't': 163822, 'a': 145071, 'o': 144498, 'h': 122293, 'n': 121943, 'i': 112555, 's': 109990, 'r': 97882, ...})

# %%
from nltk.tokenize import word_tokenize

word_tokens  = word_tokenize(book4)
word_tokens
# Out:
# ['\ufeffThe',
#  'Project',
#  'Gutenberg',
#  'eBook',
#  'of',
#  'Don',
#  'Quixote',
#  'This',
#  'ebook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'in',
#  'the',
#  'United',
#  'States',
#  'and',
#  'most',
#  'other',
#  'parts',
#  'of',
#  'the',
#  'world',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restrictions',
#  'whatsoever',
#  '.',
#  'You',
#  'may',
#  'copy',
#  'it',
#  ',',
#  'give',
#  'it',
#  'away',
#  'or',
#  're-use',
#  'it',
#  'under',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'Project',
#  'Gutenberg',
#  'License',
#  'included',
#  'with',
#  'this',
#  'ebook',
#  'or',
#  'online',
#  'at',
#  'www.gutenberg.org',
#  '.',
#  'If',
#  'you',
#  'are',
#  'not',
#  'located',
#  'in',
#  'the',
#  'United',
#  'States',
#  ',',
#  'you',
#  'will',
#  'have',
#  'to',
#  'check',
#  'the',
#  'laws',
#  'of',
#  'the',
#  'country',
#  'where',
#  'you',
#  'are',
# ...

# %%
fdist_example = FreqDist(word_tokens)
fdist_example
# Out:
# FreqDist({',': 36918, 'the': 20990, 'and': 17027, 'to': 13570, 'of': 12980, 'that': 7676, 'a': 7018, 'in': 6955, 'I': 6622, ';': 6059, ...})

# %% [markdown]
# ## Exercises - 2 : Word Clouds and frequency counts

# %%
pip install wordcloud
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.8/222.8 kB 9.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wordcloud: filename=wordcloud-1.9.2-cp311-cp311-macosx_11_0_arm64.whl size=151975 sha256=4394ba77657b92d23da008f1c765f0f46f3c9aa242d2e26df46e165564422dd9
#   Stored in directory: /Users/mohdtalibakhtar/Library/Caches/pip/wheels/3f/c6/5a/89824e1846baaa6d6d54b3a7b1e7deecc9ae6e7ed30a1c8b0e
# Successfully built wordcloud
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import matplotlib

# %%
wordcloud = WordCloud(width = 1000, height = 700, 
                background_color ='black', colormap=matplotlib.cm.autumn,
                min_font_size = 10).generate(str(word_tokens))
plt.imshow(wordcloud)

# %%
numCharacters = len(word_tokens)
numoccurrences = fdist_example

# %%
import numpy as np

# %%
interactions_characters =np.zeros(( numCharacters, numCharacters )) 
for i in range (numCharacters-1):
    for j in range (i+1, numCharacters):
        for loc_i in range (numoccurrences [i]):
            for loc_j in range (numoccurrences [j] ):
                dist = abs (positions_characters [i] [loc_i]-positions_characters [j] [loc_j])
                if (dist <500):
                    interactions_characters [i,j]= interactions_characters [i,j]+1
                    interactions_characters [j,i]= interactions_characters [j,i]+1

# %%
G1 = nx.from_numpy_matrix(interactions_characters)
